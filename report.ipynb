# %% [markdown]
# ## ATML Group 3b Project report

# %% [markdown]
# ## Approach description
#
# We try to replicate the results of *et al. Bheda and Radpour* following their reseach paper on recognizing gestures. We use same dataset and try to build the same model. We futher improve their model to get even more accuracy.
#
# We train network to minimize cross-entropy loss for gesture classification, using Adam optimizer. The changed network uses different dropout rates, as well as weight decay slightly different augmented data for better regularization.
#
# We futher improve performance results by letting the dataset train on the VGG network (https://arxiv.org/abs/1409.1556). For this network we have following parameters:
#
# todo add parameters
#
# Script for training is in train.py, data processing pipeline in dataset.py
#
# We used accuracy as a metric to evaluate our solution.

# %% [markdown]
# ## Results
#
# Model | Train accuracy [\%] | Valid accuracy [\%] | Test accuracy [\%]
# --- | --- | --- | ---
# Raw model | 0 | 0 | 0
# Improved model | 0 | 0 | 0
# VGG | 0 | **0** | 0

# %% [markdown]
# ### Learning curves
# todo insert graphics from server

# %% [markdown]
# ### Network Architecture
# Raw : <img src="https://raw.githubusercontent.com/milibiswas/ATML_GestureRecognition_CNN/master/pic/raw.jpg?sanitize=true&raw=true" />
#
# Improved :
#
# VGG: <img src="https://raw.githubusercontent.com/milibiswas/ATML_GestureRecognition_CNN/master/pic/vgg.png?sanitize=true&raw=true" />

# %%
# example of train data
import torch
from PIL import Image
# Load sample image
import numpy as np
image = Image.open('test/dataset/messeydataset/hand5_0_bot_seg_1_cropped.png').convert('L')
image = np.array(image)
# Show image
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(image, cmap='gray')

# %% [markdown]
# ## Example of use

# %% [markdown]
# Raw network

# %% [markdown]
# Improved network

# %% [markdown]
# Vgg network
